# %%
import pandas as pd
import sentencepiece as spm

# %%
df = pd.read_json('output\General_train_text_chunk_1_cleaned.jsonl', lines = True)

# %%
# df['cleaned_abstract'] = df['cleaned_abstract'].apply(lambda x: 'sostok ' + x + ' eostok')

# %%
df.columns
# Out:
# Index(['cleaned_text', 'cleaned_abstract', 'text_token_length',
#        'abstract_token_length'],
#       dtype='object')

# %%
spm.SentencePieceTrainer.Train(input = ['output\General_train_text_chunk_1_cleaned.jsonl','output\General_train_text_chunk_2_cleaned.jsonl','output\General_train_text_chunk_3_cleaned.jsonl','output\General_train_text_chunk_4_cleaned.jsonl','output\General_train_text_chunk_5_cleaned.jsonl'], model_prefix = 'bpe', vocab_size = 6000)

# %%
sp = spm.SentencePieceProcessor(model_file = 'bpe.model')

# %%
for i in range(len(df)):
    text = sp.encode(df.at[i, 'cleaned_text'])
    abstract = sp.encode(df.at[i, 'cleaned_abstract'])
    df.at[i, 'text_token_length'] = int(len(text))
    df.at[i, 'abstract_token_length'] = int(len(abstract))

# %%
df
# Out:
#                                             cleaned_text  \
# 0      (cnn) -- Flamboyant carnival musician michel m...
# 1      Kenyan counterterrorism sources are looking at...
# 2      Unmanned aerial vehicles aren't generally thou...
# 3      Washington (cnn) -- One of two photojournalist...
# 4      Hundreds of anti-abortion activists gathered i...
# ...                                                  ...
# 16224  By . James chapman . Published: . 11:06 est, 1...
# 16225  Published: . 14:16 est, 1 august 2012 . | . Up...
# 16226  By . Daily mail reporter . Published: . 08:58 ...
# 16227  By . Larisa brown . Published: . 12:08 est, 6 ...
# 16228  By . Daily mail reporter . Published: . 15:15 ...
#
#                                         cleaned_abstract  text_token_length  \
# 0      sostok New: streets fill with jubilant michel ...                632
# 1      sostok A norwegian citizen of somali descent i...               1257
# ...

# %%
print(min(df['text_token_length']), min(df['abstract_token_length']))
# Out:
# 80 27

# %%
df_filterd = df[
    (df['text_token_length'] <= 2500) &
    (df['text_token_length'] >= 250) & 
    (df['abstract_token_length'] <= 140) &
    (df['abstract_token_length'] >= 30)
]
df_filterd
# Out:
#                                             cleaned_text  \
# 0      (cnn) -- Flamboyant carnival musician michel m...
# 1      Kenyan counterterrorism sources are looking at...
# 2      Unmanned aerial vehicles aren't generally thou...
# 3      Washington (cnn) -- One of two photojournalist...
# 4      Hundreds of anti-abortion activists gathered i...
# ...                                                  ...
# 16224  By . James chapman . Published: . 11:06 est, 1...
# 16225  Published: . 14:16 est, 1 august 2012 . | . Up...
# 16226  By . Daily mail reporter . Published: . 08:58 ...
# 16227  By . Larisa brown . Published: . 12:08 est, 6 ...
# 16228  By . Daily mail reporter . Published: . 15:15 ...
#
#                                         cleaned_abstract  text_token_length  \
# 0      sostok New: streets fill with jubilant michel ...                632
# 1      sostok A norwegian citizen of somali descent i...               1257
# ...

# %%
print(min(df_filterd['text_token_length']), min(df_filterd['abstract_token_length']))
# Out:
# 250 30

# %%
df_filterd.reset_index(drop = True)
# Out:
#                                             cleaned_text  \
# 0      (cnn) -- Flamboyant carnival musician michel m...
# 1      Kenyan counterterrorism sources are looking at...
# 2      Unmanned aerial vehicles aren't generally thou...
# 3      Washington (cnn) -- One of two photojournalist...
# 4      Hundreds of anti-abortion activists gathered i...
# ...                                                  ...
# 16066  By . James chapman . Published: . 11:06 est, 1...
# 16067  Published: . 14:16 est, 1 august 2012 . | . Up...
# 16068  By . Daily mail reporter . Published: . 08:58 ...
# 16069  By . Larisa brown . Published: . 12:08 est, 6 ...
# 16070  By . Daily mail reporter . Published: . 15:15 ...
#
#                                         cleaned_abstract  text_token_length  \
# 0      sostok New: streets fill with jubilant michel ...                632
# 1      sostok A norwegian citizen of somali descent i...               1257
# ...

# %%
df_filterd.columns
# Out:
# Index(['cleaned_text', 'cleaned_abstract', 'text_token_length',
#        'abstract_token_length'],
#       dtype='object')

# %%
text_tokens = []
abstract_tokens = []

for tokens in range(len(df_filterd)):
    text = sp.encode(df_filterd.iloc[tokens]['cleaned_text'])
    abstract = sp.encode(df_filterd.iloc[tokens]['cleaned_abstract'])
    text_tokens.append(text)
    abstract_tokens.append(abstract)

# %%
df_filterd.to_json('output\General_train_text_chunk_5_cleaned.jsonl', orient = 'records', lines = True)
df_tokens = pd.DataFrame(list(zip(text_tokens, abstract_tokens)), columns = ['text_tokens', 'abstract_tokens'])
df_tokens
# Out:
#                                              text_tokens  \
# 0      [98, 101, 66, 47, 408, 2321, 524, 37, 366, 215...
# 1      [17, 0, 136, 37, 137, 3101, 243, 93, 133, 1303...
# 2      [2705, 170, 1715, 8, 49, 587, 2957, 58, 31, 12...
# 3      [17, 1905, 98, 101, 66, 47, 909, 9, 105, 1896,...
# 4      [5000, 3, 9, 1107, 16, 1071, 133, 677, 2136, 3...
# ...                                                  ...
# 16066  [2658, 15, 5383, 1102, 107, 170, 15, 2473, 60,...
# 16067  [2473, 60, 15, 821, 60, 4150, 1010, 5, 413, 94...
# 16068  [2658, 15, 4462, 2812, 2873, 15, 2473, 60, 15,...
# 16069  [2658, 15, 1306, 169, 3, 39, 1469, 15, 2473, 6...
# 16070  [2658, 15, 4462, 2812, 2873, 15, 2473, 60, 15,...
#
#                                          abstract_tokens
# 0      [17, 3, 46, 517, 60, 2407, 4023, 29, 1354, 179...
# 1      [17, 3, 46, 88, 1748, 149, 114, 391, 3025, 9, ...
# 2      [17, 3, 46, 27, 104, 39, 52, 1868, 4, 2901, 3,...
# ...

# %%
df_tokens.to_json('output/train_tokens_5.jsonl', orient = 'records', lines = True)

# %%
from pymongo import MongoClient

MONGO_URI = "mongodb+srv://hp333854:hp333854@cluster0.itbg0zx.mongodb.net/file_db?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(MONGO_URI)
db = client["file_db"]

print("✅ Connected to:", db.name)
# print("📂 Collections:", db.list_collection_names())
# Out:
# ✅ Connected to: file_db
